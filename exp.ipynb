# %%
import pathlib
def get_file(path):
    current_path = pathlib.Path.cwd()
    pa = pathlib.Path(current_path)
    p = pathlib.Path(path)
    a = pa/p
    return a

# %%
file_dir = 'coco-dataset/data'
path = get_file(file_dir)
path
# Out:
# WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data')

# %%
img = []
text = []
for i, j in enumerate(path.iterdir()):
    if j.suffix == '.jpg':
        img.append(j)
    elif j.suffix == '.txt':
        text.append(j)

# %%
img
# Out:
# [WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/0.jpg'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/1.jpg'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10.jpg'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/100.jpg'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/1000.jpg'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10000.jpg'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10001.jpg'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10002.jpg'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10003.jpg'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10004.jpg'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10005.jpg'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10006.jpg'),
# ...

# %%
text
# Out:
# [WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/0.txt'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/1.txt'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10.txt'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/100.txt'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/1000.txt'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10000.txt'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10001.txt'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10002.txt'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10003.txt'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10004.txt'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10005.txt'),
#  WindowsPath('e:/ML/NLP/common/text-detection/coco-dataset/data/10006.txt'),
# ...

# %%
a = img[0]
print(a)
# Out:
# e:\ML\NLP\common\text-detection\coco-dataset\data\0.jpg

# %%
from PIL import Image

Image.open(a)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x425>

# %%
text[0].read_text()
# Out:
# '0 0.7859375 0.5670588235294117 0.046875 0.023529411764705882'
